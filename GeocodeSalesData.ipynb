# %%
import pandas as pd

from DATA9003.LoadSales import LoadSalesData
from DATA9003.LoadSales import GeocodeAddresses

# %%
HouseSales = LoadSalesData(SalesDir="D:/MyData/property")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283881 entries, 0 to 283880
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     283881 non-null  int64
#  1   borough        283881 non-null  object
#  2   neighbourhood  283881 non-null  object
#  3   address        283881 non-null  object
#  4   zipcode        283881 non-null  float64
#  5   resi_units     283881 non-null  float64
#  6   comm_units     283881 non-null  float64
#  7   total_units    283881 non-null  float64
#  8   land_sqft      283881 non-null  float64
#  9   gross_sqft     283881 non-null  float64
#  10  year_built     283881 non-null  float64
#  11  tax_cls        283881 non-null  float64
#  12  building_cls   283881 non-null  object
#  13  sale_price     283881 non-null  float64
#  14  sale_date      283881 non-null  object
# dtypes: float64(9), int64(1), object(5)
# memory usage: 32.5+ MB
# None

# %%
HouseCoords = GeocodeAddresses(HouseSales, "D:/MyData/property")
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('524 WARWICK STREET                       , NEW YORK, NEW YORK, 11207',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\eoink\anaconda3\lib\site-packages\urllib3\connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "C:\Users\eoink\anaconda3\lib\site-packages\urllib3\util\connection.py", line 95, in create_connection
#     raise err
#   File "C:\Users\eoink\anaconda3\lib\site-packages\urllib3\util\connection.py", line 85, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\eoink\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\eoink\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 386, in _make_request
# ...

# %%
HouseCoords.to_csv("D:/MyData/property/PropertyCoords.csv",
                   index=False)
